# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("balloon_launch.txt", skiprows=138)

# %%
mins = data[:,0]
secs = data[:,1]
temp = data[:,5]

time = 60 * mins + secs

# %%
plt.plot(time,temp)

# %%
plt.plot(time,temp,color='red',lw=2)
