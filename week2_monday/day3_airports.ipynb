# %% [markdown]
# ### Pandas Dataframe

# %% [markdown]
# In this activity, you will be exploring airport data and answering a series of questions listed at the end.

# %% [markdown]
# ### 0: Prerequisites - Pandas functions and attributes

# %%
# read the airports csv into pandas as a dataframe and call it airports_df
import pandas as pd
import numpy as np

# %%
airports_df = pd.read_csv('http://136.183.56.191/DSA501public/airports.csv')
airports_df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# 0      Bensalem                no      00A       NaN        00A       NaN
# 1         Leoti                no     00AA       NaN       00AA       NaN
# 2  Anchor Point                no     00AK       NaN       00AK       NaN
# 3       Harvest                no     00AL       NaN       00AL       NaN
# 4       Newport                no      NaN       NaN        NaN       NaN
#
#   wikipedia_link keywords
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN     00AR

# %%
airports_df = airports_df.set_index('name')
airports_df.head()
# Out:
#                                         id ident           type  latitude_deg  \
# name
# Total Rf Heliport                     6523   00A       heliport     40.070801
# Aero B Ranch Airport                323361  00AA  small_airport     38.704022
# Lowell Field                          6524  00AK  small_airport     59.949200
# Epps Airpark                          6525  00AL  small_airport     34.864799
# Newport Hospital & Clinic Heliport    6526  00AR         closed     35.608700
#
#                                     longitude_deg  elevation_ft continent  \
# name
# Total Rf Heliport                      -74.933601          11.0       NaN
# Aero B Ranch Airport                  -101.473911        3435.0       NaN
# Lowell Field                          -151.695999         450.0       NaN
# Epps Airpark                           -86.770302         820.0       NaN
# Newport Hospital & Clinic Heliport     -91.254898         237.0       NaN
#
#                                    iso_country iso_region  municipality  \
# name
# Total Rf Heliport                           US      US-PA      Bensalem
# Aero B Ranch Airport                        US      US-KS         Leoti
# Lowell Field                                US      US-AK  Anchor Point
# Epps Airpark                                US      US-AL       Harvest
# Newport Hospital & Clinic Heliport          US      US-AR       Newport
#
#                                    scheduled_service gps_code iata_code  \
# name
# Total Rf Heliport                                 no      00A       NaN
# Aero B Ranch Airport                              no     00AA       NaN
# Lowell Field                                      no     00AK       NaN
# Epps Airpark                                      no     00AL       NaN
# Newport Hospital & Clinic Heliport                no      NaN       NaN
#
#                                    local_code home_link wikipedia_link  \
# name
# Total Rf Heliport                         00A       NaN            NaN
# Aero B Ranch Airport                     00AA       NaN            NaN
# Lowell Field                             00AK       NaN            NaN
# Epps Airpark                             00AL       NaN            NaN
# Newport Hospital & Clinic Heliport        NaN       NaN            NaN
#
#                                    keywords
# name
# Total Rf Heliport                       NaN
# Aero B Ranch Airport                    NaN
# Lowell Field                            NaN
# Epps Airpark                            NaN
# Newport Hospital & Clinic Heliport     00AR

# %% [markdown]
# ### Selecting columns and rows
#
# To work with a column or row, use bracket notation as in these examples.

# %%
# select a column using it's name
airports_df['municipality']
# Out:
# name
# Total Rf Heliport                             Bensalem
# Aero B Ranch Airport                             Leoti
# Lowell Field                              Anchor Point
# Epps Airpark                                   Harvest
# Newport Hospital & Clinic Heliport             Newport
#                                             ...
# Yingkou Lanqi Airport                          Yingkou
# Shenyang Dongta Airport                       Shenyang
# Sealand Helipad                                Sealand
# Glorioso Islands Airstrip             Grande Glorieuse
# Satsuma Iōjima Airport                    Mishima-Mura
# Name: municipality, Length: 52921, dtype: object

# %%
# show a row using it's index name (like in a python dictionary)
airports_df.loc['Siachen Glacier AFS Airport']
# Out:
# id                      35129
# ident                 IN-0001
# type                 heliport
# latitude_deg             35.5
# longitude_deg              77
# elevation_ft            22000
# continent                  AS
# iso_country                IN
# iso_region              IN-JK
# municipality              NaN
# scheduled_service          no
# gps_code                  NaN
# iata_code                 NaN
# local_code                NaN
# home_link                 NaN
# wikipedia_link            NaN
# keywords                  NaN
# Name: Siachen Glacier AFS Airport, dtype: object

# %%
# show row using numerical index (like in a python list)
airports_df.iloc[3]
# Out:
# id                            6525
# ident                         00AL
# type                 small_airport
# latitude_deg               34.8648
# longitude_deg             -86.7703
# elevation_ft                   820
# continent                      NaN
# iso_country                     US
# iso_region                   US-AL
# municipality               Harvest
# scheduled_service               no
# gps_code                      00AL
# iata_code                      NaN
# local_code                    00AL
# home_link                      NaN
# wikipedia_link                 NaN
# keywords                       NaN
# Name: Epps Airpark, dtype: object

# %% [markdown]
# ### Functions for examining pandas dataframes
# These are some pandas functions that work on whole DataFrames or on columns or rows, which are pandas Series. Some functions will only work if the column, row or entire dataframe is numerical or of another specific type.

# %% [markdown]
# #### Try one of these functions on the airport dataframe. Determine what it does.
#
# * describe()
# * info()
# * head()
# * tail()
# * duplicated()

# %%
# your code here

airports_df.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft
# count   52921.000000  52921.000000   52921.000000  47004.000000
# mean    73480.614709     25.537839     -37.172830   1224.977874
# std    111930.291948     27.470424      78.081630   1572.929613
# min         2.000000    -90.000000    -179.876999  -1266.000000
# 25%     13349.000000      6.984440     -92.009300    205.000000
# 50%     26680.000000     36.443802     -72.776667    715.000000
# 75%     42407.000000     43.963799      13.193611   1481.000000
# max    326499.000000     82.750000     179.975700  22000.000000

# %% [markdown]
# #### Try one of these functions on a numerical column the airport dataframe. Determine what it does. Does it require any parameters? Does it return anything?
#
# * sum()
# * count()
# * min()
# * max()
# * sort_values()
# * idxmax()
# * idxmin()
# * isnull()
# * value_counts()
# * unique()
# * nunique()

# %%
# your code here
airports_df['elevation_ft'].idxmax()
# Out:
# 'Siachen Glacier AFS Airport'

# %% [markdown]
# #### Try one of these on a row in the airports dataframe.
# * nunique()
# * isnull()

# %%
# your code here
print(airports_df.iloc[21])
airports_df.iloc[21].nunique()
# Out:
# id                       6540
# ident                    00IN
# type                 heliport
# latitude_deg          41.5114
# longitude_deg        -87.2606
# elevation_ft              634
# continent                 NaN
# iso_country                US
# iso_region              US-IN
# municipality           Hobart
# scheduled_service          no
# gps_code                 00IN
# iata_code                 NaN
# local_code               00IN
# home_link                 NaN
# wikipedia_link            NaN
# keywords                  NaN
# Name: St Mary Medical Center Heliport, dtype: object
# 10

# %% [markdown]
# Many of the functions above, and even the read_csv function have optional parameters. Try the examples below. For more parameters, look up any function in the pandas documentation https://pandas.pydata.org/pandas-docs/stable/.

# %%
# try this
airports_df.head(10)
# Out:
#                                         id ident           type  latitude_deg  \
# name
# Total Rf Heliport                     6523   00A       heliport     40.070801
# Aero B Ranch Airport                323361  00AA  small_airport     38.704022
# Lowell Field                          6524  00AK  small_airport     59.949200
# Epps Airpark                          6525  00AL  small_airport     34.864799
# Newport Hospital & Clinic Heliport    6526  00AR         closed     35.608700
# Fulton Airport                      322127  00AS  small_airport     34.942803
# Cordes Airport                        6527  00AZ  small_airport     34.305599
# Goldstone /Gts/ Airport               6528  00CA  small_airport     35.350498
# Williams Ag Airport                 324424  00CL  small_airport     39.427188
# Kitchen Creek Helibase Heliport     322658  00CN       heliport     32.727374
#
#                                     longitude_deg  elevation_ft continent  \
# name
# Total Rf Heliport                      -74.933601          11.0       NaN
# Aero B Ranch Airport                  -101.473911        3435.0       NaN
# Lowell Field                          -151.695999         450.0       NaN
# Epps Airpark                           -86.770302         820.0       NaN
# Newport Hospital & Clinic Heliport     -91.254898         237.0       NaN
# Fulton Airport                         -97.818019        1100.0       NaN
# Cordes Airport                        -112.165001        3810.0       NaN
# Goldstone /Gts/ Airport               -116.888000        3038.0       NaN
# Williams Ag Airport                   -121.763427          87.0       NaN
# Kitchen Creek Helibase Heliport       -116.459742        3350.0       NaN
#
#                                    iso_country iso_region  municipality  \
# name
# Total Rf Heliport                           US      US-PA      Bensalem
# Aero B Ranch Airport                        US      US-KS         Leoti
# Lowell Field                                US      US-AK  Anchor Point
# Epps Airpark                                US      US-AL       Harvest
# Newport Hospital & Clinic Heliport          US      US-AR       Newport
# Fulton Airport                              US      US-OK          Alex
# Cordes Airport                              US      US-AZ        Cordes
# Goldstone /Gts/ Airport                     US      US-CA       Barstow
# Williams Ag Airport                         US      US-CA         Biggs
# Kitchen Creek Helibase Heliport             US      US-CA   Pine Valley
#
#                                    scheduled_service gps_code iata_code  \
# name
# Total Rf Heliport                                 no      00A       NaN
# Aero B Ranch Airport                              no     00AA       NaN
# Lowell Field                                      no     00AK       NaN
# Epps Airpark                                      no     00AL       NaN
# Newport Hospital & Clinic Heliport                no      NaN       NaN
# Fulton Airport                                    no     00AS       NaN
# Cordes Airport                                    no     00AZ       NaN
# Goldstone /Gts/ Airport                           no     00CA       NaN
# Williams Ag Airport                               no     00CL       NaN
# Kitchen Creek Helibase Heliport                   no     00CN       NaN
#
#                                    local_code home_link wikipedia_link  \
# name
# Total Rf Heliport                         00A       NaN            NaN
# Aero B Ranch Airport                     00AA       NaN            NaN
# Lowell Field                             00AK       NaN            NaN
# Epps Airpark                             00AL       NaN            NaN
# Newport Hospital & Clinic Heliport        NaN       NaN            NaN
# Fulton Airport                           00AS       NaN            NaN
# Cordes Airport                           00AZ       NaN            NaN
# Goldstone /Gts/ Airport                  00CA       NaN            NaN
# Williams Ag Airport                      00CL       NaN            NaN
# Kitchen Creek Helibase Heliport          00CN       NaN            NaN
#
#                                    keywords
# name
# Total Rf Heliport                       NaN
# Aero B Ranch Airport                    NaN
# Lowell Field                            NaN
# Epps Airpark                            NaN
# Newport Hospital & Clinic Heliport     00AR
# Fulton Airport                          NaN
# Cordes Airport                          NaN
# Goldstone /Gts/ Airport                 NaN
# Williams Ag Airport                     NaN
# Kitchen Creek Helibase Heliport         NaN

# %%
# try this
airports_df['latitude_deg'].sort_values(ascending = False)
# Out:
# name
# Disraeli Inlet Water Aerodrome    82.750000
# Alert Airport                     82.517799
# Station Nord Heliport             81.697844
# Station Nord Landing Strip        81.600000
# Tanquary Fiord Airport            81.409401
#                                     ...
# Base Belgrano II Airport         -77.874055
# McMurdo Station Pegasus Field    -77.963402
# Unión Glaciar Airport            -79.777778
# Patriot Hills Airport            -80.318298
# South Pole Station Airport       -90.000000
# Name: latitude_deg, Length: 52921, dtype: float64

# %% [markdown]
# #### Try at least two of these on the airports dataframe. These are attributes, not functions. Notice there are no parentheses.
# * shape
# * columns
# * dtypes
# * index
# * values

# %%
# your code here

# %% [markdown]
# ### Selecting individual values and other subsets of the dataframe.

# %%
# show several columns
airports_df[['municipality','type']]
# Out:
#                                         municipality            type
# name
# Total Rf Heliport                           Bensalem        heliport
# Aero B Ranch Airport                           Leoti   small_airport
# Lowell Field                            Anchor Point   small_airport
# Epps Airpark                                 Harvest   small_airport
# Newport Hospital & Clinic Heliport           Newport          closed
# ...                                              ...             ...
# Yingkou Lanqi Airport                        Yingkou  medium_airport
# Shenyang Dongta Airport                     Shenyang  medium_airport
# Sealand Helipad                              Sealand        heliport
# Glorioso Islands Airstrip           Grande Glorieuse   small_airport
# Satsuma Iōjima Airport                  Mishima-Mura   small_airport
#
# [52921 rows x 2 columns]

# %%
airports_df.iloc[[2,3,4]]
# Out:
#                                       id ident           type  latitude_deg  \
# name
# Lowell Field                        6524  00AK  small_airport     59.949200
# Epps Airpark                        6525  00AL  small_airport     34.864799
# Newport Hospital & Clinic Heliport  6526  00AR         closed     35.608700
#
#                                     longitude_deg  elevation_ft continent  \
# name
# Lowell Field                          -151.695999         450.0       NaN
# Epps Airpark                           -86.770302         820.0       NaN
# Newport Hospital & Clinic Heliport     -91.254898         237.0       NaN
#
#                                    iso_country iso_region  municipality  \
# name
# Lowell Field                                US      US-AK  Anchor Point
# Epps Airpark                                US      US-AL       Harvest
# Newport Hospital & Clinic Heliport          US      US-AR       Newport
#
#                                    scheduled_service gps_code iata_code  \
# name
# Lowell Field                                      no     00AK       NaN
# Epps Airpark                                      no     00AL       NaN
# Newport Hospital & Clinic Heliport                no      NaN       NaN
#
#                                    local_code home_link wikipedia_link  \
# name
# Lowell Field                             00AK       NaN            NaN
# Epps Airpark                             00AL       NaN            NaN
# Newport Hospital & Clinic Heliport        NaN       NaN            NaN
#
#                                    keywords
# name
# Lowell Field                            NaN
# Epps Airpark                            NaN
# Newport Hospital & Clinic Heliport     00AR

# %%
airports_df.iloc[2:5,:4]
# Out:
#                                       id ident           type  latitude_deg
# name
# Lowell Field                        6524  00AK  small_airport     59.949200
# Epps Airpark                        6525  00AL  small_airport     34.864799
# Newport Hospital & Clinic Heliport  6526  00AR         closed     35.608700

# %%
airports_df.loc[['Epps Airpark'],['municipality','type']]
# Out:
#              municipality           type
# name
# Epps Airpark      Harvest  small_airport

# %% [markdown]
# ### Boolean mask filtering

# %%
airports_df[airports_df['latitude_deg'] > 0]
type(airports_df['latitude_deg'] > 80)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 1: Airport Questions

# %% [markdown]
# ##### 1.1 Answer each the following questions using the airports data.

# %% [markdown]
# <ol type="a">
# <li> How many airports are there?
#
#   <li> Which airport is most southern?
#   <li> How many different countries are included in the dataframe?
#   <li> What is the type of the Wikipedia links data?
#   <li> Is there any missing data in the iso-region column?
#   <li> What type of airport is Groundhog Mountain Airport?
#   <li> How many airports are below sea level?
#  </ol>

# %%
# your work here
# add cells as neede
len(set(airports_df.index))
airports_df['latitude_deg'].idxmin()
len(set(airports_df['iso_country']))
airports_df['wikipedia_link'].dtypes
airports_df.loc['Groundhog Mountain Airport']
airports_df[airports_df['iso_region'] == None]

len(set(airports_df[airports_df['elevation_ft'] < 0].index))

len(set(airports_df.index))
# Out:
# 50150

# %% [markdown]
# ##### 1.2 There is an issue with the 'continent' column data. Find the issue by using pandas functions to examine the column. Then fix it. Hint: look up fillna.

# %%
# your work here
# add cells as needed
airports_df['continent'].unique()
airports_df['continent'][0] == float('nan')
# Out:
# False

# %% [markdown]
# ### Cleaning Data
# * research information about the data and features
# * examine data for anomalies
# * consider consequences of possible fixes
# * handle NAs
# * handle dtypes
# * confirm changes

# %% [markdown]
# #### NA, NaN, nan, null processing
# * isnull(), isna()
# * notnull()
# * dropna()
# * fillna()

# %% [markdown]
# #### dtype processing
# * astype()
# * dtypes
# * dtype
# * read_csv dtype parameter
